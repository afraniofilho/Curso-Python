# %% [markdown]
# <a href="https://colab.research.google.com/github/afraniofilho/Curso-Python/blob/main/Ancine_Grendene.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/BilheteriaObrasSemana.csv', encoding='ISO-8859-1', sep=';', decimal=',')

# %%
df.head()
# Out:
#             TITULO_ORIGINAL    TITULO_BRASILEIRO        GENERO  \
# 0                   COLLEGE  COLEGIAIS EM APUROS        Ficção
# 1       O ABORTO DOS OUTROS                  NaN  Documentário
# 2  ONDE ANDARÁ DULCE VEIGA?                  NaN        Ficção
# 3    QUAND J'ETAIS CHANTEUR  QUANDO ESTOU AMANDO        Ficção
# 4                       REC                  REC        Ficção
#
#        PAIS_ORIGEM         CPB_ROE  COPIAS  SALAS DT_INICIO_EXIBICAO  \
# 0   Estados Unidos  E1600557700000       8      8         02/01/2009
# 1           Brasil  B0800890900000       1      1         02/01/2009
# 2    Brasil, Chile  B0700801600000       1      1         02/01/2009
# 3           França  E1600545500000       1      1         02/01/2009
# 4          Espanha  E1600619700000       2      2         02/01/2009
#
#   DT_FIM_EXIBICAO  PUBLICO    RENDA     RAZAO_SOCIAL_DISTRIBUIDORA  \
# 0      08/01/2009      833  5325.00  ANTONIO FERNANDES FILMES LTDA
# ...

# %%
df.shape
# Out:
# (51176, 15)

# %%
df.columns
# Out:
# Index(['TITULO_ORIGINAL', 'TITULO_BRASILEIRO', 'GENERO', 'PAIS_ORIGEM',
#        'CPB_ROE', 'COPIAS', 'SALAS', 'DT_INICIO_EXIBICAO', 'DT_FIM_EXIBICAO',
#        'PUBLICO', 'RENDA', 'RAZAO_SOCIAL_DISTRIBUIDORA',
#        'REGISTRO_DISTRIBUIDORA', 'CNPJ_DISTRIBUIDORA', 'ANO_CINEMATOGRAFICO'],
#       dtype='object')

# %%
df.tail()
# Out:
#       TITULO_ORIGINAL               TITULO_BRASILEIRO  GENERO  \
# 51171   BELLE DE JOUR                 A BELA DA TARDE  Ficção
# 51172         BLOW-UP  BLOW-UP - DEPOIS DAQUELE BEIJO  Ficção
# 51173            COLO                            COLO  Ficção
# 51174   GRADUATE, THE    A PRIMEIRA NOITE DE UM HOMEM  Ficção
# 51175     JEUNE FEMME                    JOVEM MULHER  Ficção
#
#                                 PAIS_ORIGEM         CPB_ROE  COPIAS  SALAS  \
# 51171                        França, Itália  E1700492900000       4      4
# 51172   Estados Unidos, Itália, Reino Unido  E1600672700000       1      1
# 51173                              Portugal  E1700484800000       2      2
# 51174                        Estados Unidos  E1402602600000       1      1
# 51175                                França  E1700522000000       5     10
#
#       DT_INICIO_EXIBICAO DT_FIM_EXIBICAO  PUBLICO     RENDA  \
# 51171         28/12/2017      03/01/2018      218   3058.00
# ...

# %%
# Quais anos tiveram mais lançamentos?

# %%
df['ANO_CINEMATOGRAFICO'].value_counts()
# Out:
# 2009    6205
# 2015    5950
# 2011    5786
# 2014    5785
# 2010    5685
# 2013    5521
# 2016    5513
# 2012    5495
# 2017    5236
# Name: ANO_CINEMATOGRAFICO, dtype: int64

# %%
# Qual o filme com maior público semanal?

# %%
df['PUBLICO'].max()
# Out:
# 4074628

# %%
df[df['PUBLICO'] == df['PUBLICO'].max()]
# Out:
#                   TITULO_ORIGINAL              TITULO_BRASILEIRO  GENERO  \
# 42176  CAPTAIN AMERICA: CIVIL WAR  CAPITÃO AMÉRICA: GUERRA CIVIL  Ficção
#
#            PAIS_ORIGEM         CPB_ROE  COPIAS  SALAS DT_INICIO_EXIBICAO  \
# 42176   Estados Unidos  E1600129800000       0   1635         28/04/2016
#
#       DT_FIM_EXIBICAO  PUBLICO       RENDA  \
# 42176      04/05/2016  4074628  61046213.0
#
#                    RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 42176  THE WALT DISNEY COMPANY (BRASIL) LTDA.                   18398
#
#        CNPJ_DISTRIBUIDORA  ANO_CINEMATOGRAFICO
# 42176  73.042.962/0001-87                 2016
